# %%
dynamic_data_alpha_raw[1][1]

# %%
# Cell 1: Import libraries and modules
import torch
import import_ipynb
from data_preprocessing import process_band
from data_combiner import combine_band_data
from analysis_pipeline import run_all_analyses
from netwrks_2 import MultiBandAttentionFusion
from explain_utils import (
    explain_model_predictions,
    print_explanation_results,
    explain_single_graph
)

# %%
# Cell 2: Load your data
PATH_TO_SAVED_DYNAMIC_alpha = r"C:\Users\fathi\test\Granger_all_dynamic_data_overlap50.pt"
PATH_TO_SAVED_DYNAMIC_beta = r"C:\Users\fathi\test\Granger_all_dynamic_data_overlap50_beta.pt"

dynamic_data_alpha_raw = torch.load(PATH_TO_SAVED_DYNAMIC_alpha)
dynamic_data_beta_raw = torch.load(PATH_TO_SAVED_DYNAMIC_beta)


device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# Cell 3: Process each band
train_alpha, test_alpha, dynamic_alpha = process_band(dynamic_data_alpha_raw)
train_beta, test_beta, dynamic_beta = process_band(dynamic_data_beta_raw)

print(f"Alpha band: {len(dynamic_alpha)} subjects")
print(f"Beta band: {len(dynamic_beta)} subjects")

# Cell 4: Combine bands for multi-band analysis
band_data_list = [dynamic_alpha, dynamic_beta]
combined_dataset = combine_band_data(band_data_list)
band_names = ['Alpha', 'Beta']

print(f"Combined dataset: {len(combined_dataset)} subjects")

# Cell 5: Run analysis
results = run_all_analyses(combined_dataset, model_class=MultiBandAttentionFusion, band_names=band_names)
# Cell 6: Access results
best_model = results['best_single_model']
ensemble_model = results['ensemble_model']
fold_metrics = results['fold_metrics']
cv_results = results['cv_results']

print("\nFinal Results:")
print(f"Best CV F1: {cv_results['avg_f1']:.4f}")
print(f"Best CV Accuracy: {cv_results['avg_accuracy']:.4f}")
if cv_results['avg_band_importance']:
    print("Band Importance:")
    for band, importance in cv_results['avg_band_importance'].items():
        print(f"  {band}: {importance:.4f}")

###

# === EXPLANATION PHASE ===
explanations = explain_model_predictions(best_model, combined_dataset, device, band_names=band_names)
print_explanation_results(explanations)




# Cell 7: Optional - Save models
torch.save(best_model.state_dict(), 'best_model.pt')
torch.save(ensemble_model.state_dict(), 'ensemble_model.pt')
# Optional: Print a single graph shape for sanity check
sample_band_idx = 0
sample_time_idx = 0
sample_subject = combined_dataset[0]
sample_graph = sample_subject[sample_band_idx][sample_time_idx]

print("Sample graph shape check:")
print("  x shape:", sample_graph.x.shape)
print("  edge_index shape:", sample_graph.edge_index.shape)





# Pick one subject and a specific band and time point
subject_idx = 0
band_idx = 0
time_idx = 0

# Select subject data
subject_data = combined_dataset[subject_idx]
graph = subject_data[band_idx][time_idx]
target_class = graph.y.item()

# Use the trained model (best_model)
model = best_model.to(device)
model.eval()  # VERY important for consistent inference

# Run explanation
explanation = explain_single_graph(
    model=model,
    graph=graph,
    full_batch=subject_data,
    band_idx=band_idx,
    time_idx=time_idx,
    target_class=target_class,
    device=device
)

# Save or print explanation
torch.save(explanations, "full_model_explanations.pt")

print("Explanation saved.")
# Out:
# C:\Users\fathi\AppData\Local\Temp\ipykernel_14472\3718588443.py:5: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   dynamic_data_alpha_raw = torch.load(PATH_TO_SAVED_DYNAMIC_alpha)
# C:\Users\fathi\AppData\Local\Temp\ipykernel_14472\3718588443.py:6: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   dynamic_data_beta_raw = torch.load(PATH_TO_SAVED_DYNAMIC_beta)
# Alpha band: 52 subjects
# Beta band: 52 subjects
# Combined dataset: 52 subjects
# Using device: cpu
#
# ===== Fold 1/2 =====
# Training set: Class 0: 15, Class 1: 11
# Validation set: Class 0: 14, Class 1: 12
# c:\Users\fathi\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\optim\lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# Using class weights: [0.8666667 1.7727273]
# Training Fold 1:   0%|          | 0/1 [00:00<?, ?it/s]c:\Users\fathi\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Training Fold 1: 100%|██████████| 1/1 [00:34<00:00, 34.63s/it, best_epoch=1, best_f1=0.3769, conf=0.62, train_loss=2.0892, val_f1=0.3769, val_loss=0.6874]
# Fold 1 - Best Epoch: 1
# Best Validation F1: 0.3769
# Accuracy: 0.5385 | Recall: 0.5385 | Precision: 0.2899
# Average prediction confidence: 0.6188
# Confusion Matrix:
# [[14  0]
#  [12  0]]
#
# Band Importance Analysis (Fold 1):
# Alpha: 0.0140 (1.4%)
# Beta: 0.9860 (98.6%)
#
# ===== Fold 2/2 =====
# Training set: Class 0: 14, Class 1: 12
# Validation set: Class 0: 15, Class 1: 11
# c:\Users\fathi\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\optim\lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# Using class weights: [0.9285714 1.625    ]
# Training Fold 2: 100%|██████████| 1/1 [00:34<00:00, 34.30s/it, best_epoch=1, best_f1=0.5032, conf=0.55, train_loss=1.4345, val_f1=0.5032, val_loss=0.6719]
# Fold 2 - Best Epoch: 1
# Best Validation F1: 0.5032
# Accuracy: 0.6154 | Recall: 0.6154 | Precision: 0.7692
# Average prediction confidence: 0.5476
# Confusion Matrix:
# [[15  0]
#  [10  1]]
#
# Band Importance Analysis (Fold 2):
# Alpha: 0.9433 (94.3%)
# Beta: 0.0567 (5.7%)
#
# ===== Cross-Validation Results =====
# Average F1: 0.4401
# Average Accuracy: 0.5769
# Average Recall: 0.5769
# Average Precision: 0.5296
# F1 Standard Deviation: 0.0631
#
# Average Band Importance Across All Folds:
# Alpha: 0.4787 (47.9%)
# Beta: 0.5213 (52.1%)
#
# ===== Analysis Summary =====
# Cross-Validation F1: 0.4401 ± 0.0631
# Cross-Validation Accuracy: 0.5769 ± 0.0385
#
# Final Results:
# Best CV F1: 0.4401
# Best CV Accuracy: 0.5769
# Band Importance:
#   Alpha: 0.4787
#   Beta: 0.5213
# Explaining subject 1/52 (Label: 1)
#   Analyzing Alpha band...
#     Explaining time step 0 ...
# c:\Users\fathi\AppData\Local\Programs\Python\Python312\Lib\site-packages\captum\attr\_utils\batching.py:51: UserWarning: Internal batch size cannot be less than the number of input examples. Defaulting to internal batch size of 19 equal to the number of examples.
#   warnings.warn(
#     Done with time step 0
#     Explaining time step 1 ...
#     Done with time step 1
#     Explaining time step 2 ...
#     Done with time step 2
#     Explaining time step 3 ...
#     Done with time step 3
#     Explaining time step 4 ...
#     Done with time step 4
#     Explaining time step 5 ...
#     Done with time step 5
#     Explaining time step 6 ...
#     Done with time step 6
#     Explaining time step 7 ...
#     Done with time step 7
#     Explaining time step 8 ...
#     Done with time step 8
#     Explaining time step 9 ...
#     Done with time step 9
#     Explaining time step 10 ...
#     Done with time step 10
#     Explaining time step 11 ...
#     Done with time step 11
#     Explaining time step 12 ...
#     Done with time step 12
#     Explaining time step 13 ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 43
#      38         print(f"  {band}: {importance:.4f}")
#      40 ###
#      41
#      42 # === EXPLANATION PHASE ===
# ---> 43 explanations = explain_model_predictions(best_model, combined_dataset, device, band_names=band_names)
#      44 print_explanation_results(explanations)
#      49 # Cell 7: Optional - Save models
#
# File <string>:55, in explain_model_predictions(model, dataset, device, num_subjects, band_names)
#
# File <string>:123, in explain_single_graph(model, graph, full_batch, band_idx, time_idx, target_class, device)
#
# File c:\Users\fathi\AppData\Local\Programs\Python\Python312\Lib\site-packages\captum\log\dummy_log.py:39, in log_usage.<locals>._log_usage.<locals>.wrapper(*args, **kwargs)
#      35 @wraps(func)
#      36 # pyre-fixme[53]: Captured variable `func` is not annotated.
#      37 # pyre-fixme[3]: Return type must be annotated.
#      38 def wrapper(*args: Any, **kwargs: Any):
# ---> 39     return func(*args, **kwargs)
#
# File c:\Users\fathi\AppData\Local\Programs\Python\Python312\Lib\site-packages\captum\attr\_core\integrated_gradients.py:277, in IntegratedGradients.attribute(self, inputs, baselines, target, additional_forward_args, n_steps, method, internal_batch_size, return_convergence_delta)
#     275 if internal_batch_size is not None:
#     276     num_examples = formatted_inputs[0].shape[0]
# --> 277     attributions = _batch_attribution(
#     278         self,
#     279         num_examples,
#     280         internal_batch_size,
#     281         n_steps,
#     282         inputs=formatted_inputs,
#     283         baselines=formatted_baselines,
#     284         target=target,
#     285         additional_forward_args=additional_forward_args,
#     286         method=method,
#     287     )
#     288 else:
#     289     attributions = self._attribute(
#     290         inputs=formatted_inputs,
#     291         baselines=formatted_baselines,
#    (...)
#     295         method=method,
#     296     )
#
# File c:\Users\fathi\AppData\Local\Programs\Python\Python312\Lib\site-packages\captum\attr\_utils\batching.py:86, in _batch_attribution(attr_method, num_examples, internal_batch_size, n_steps, include_endpoint, **kwargs)
#      84 step_sizes = full_step_sizes[start_step:end_step]
#      85 alphas = full_alphas[start_step:end_step]
# ---> 86 current_attr = attr_method._attribute(
#      87     **kwargs, n_steps=batch_steps, step_sizes_and_alphas=(step_sizes, alphas)
#      88 )
#      90 if total_attr is None:
#      91     total_attr = current_attr
#
# File c:\Users\fathi\AppData\Local\Programs\Python\Python312\Lib\site-packages\captum\attr\_core\integrated_gradients.py:368, in IntegratedGradients._attribute(self, inputs, baselines, target, additional_forward_args, n_steps, method, step_sizes_and_alphas)
#     365 expanded_target = _expand_target(target, n_steps)
#     367 # grads: dim -> (bsz * #steps x inputs[0].shape[1:], ...)
# --> 368 grads = self.gradient_func(
#     369     forward_fn=self.forward_func,
#     370     inputs=scaled_features_tpl,
#     371     target_ind=expanded_target,
#     372     additional_forward_args=input_additional_args,
#     373 )
#     375 # flattening grads so that we can multilpy it with step-size
#     376 # calling contiguous to avoid `memory whole` problems
#     377 scaled_grads = [
#     378     grad.contiguous().view(n_steps, -1)
#     379     * torch.tensor(step_sizes).float().view(n_steps, 1).to(grad.device)
#     380     for grad in grads
#     381 ]
#
# File c:\Users\fathi\AppData\Local\Programs\Python\Python312\Lib\site-packages\captum\_utils\gradient.py:128, in compute_gradients(forward_fn, inputs, target_ind, additional_forward_args)
#     110 r"""
#     111 Computes gradients of the output with respect to inputs for an
#     112 arbitrary forward function.
#    (...)
#     124                 arguments) if no additional arguments are required
#     125 """
#     126 with torch.autograd.set_grad_enabled(True):
#     127     # runs forward pass
# --> 128     outputs = _run_forward(forward_fn, inputs, target_ind, additional_forward_args)
#     129     # _run_forward may return future of Tensor,
#     130     # but we don't support it here now
#     131     # And it will fail before here.
#     132     outputs = cast(Tensor, outputs)
#
# File c:\Users\fathi\AppData\Local\Programs\Python\Python312\Lib\site-packages\captum\_utils\common.py:588, in _run_forward(forward_func, inputs, target, additional_forward_args)
#     585 inputs = _format_inputs(inputs)
#     586 additional_forward_args = _format_additional_forward_args(additional_forward_args)
# --> 588 output = forward_func(
#     589     *(
#     590         # pyre-fixme[60]: Concatenation not yet support for multiple variadic
#     591         #  tuples: `*inputs, *additional_forward_args`.
#     592         (*inputs, *additional_forward_args)
#     593         if additional_forward_args is not None
#     594         else inputs
#     595     )
#     596 )
#     597 if isinstance(output, torch.futures.Future):
#     598     return output.then(lambda x: _select_targets(x.value(), target))
#
# File <string>:118, in model_wrapper(x)
#
# File c:\Users\fathi\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Users\fathi\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File <string>:102, in forward(self, subjects_data)
#
# File c:\Users\fathi\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Users\fathi\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File <string>:38, in forward(self, graphs)
#
# File c:\Users\fathi\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Users\fathi\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File c:\Users\fathi\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch_geometric\nn\conv\sage_conv.py:134, in SAGEConv.forward(self, x, edge_index, size)
#     131     x = (self.lin(x[0]).relu(), x[1])
#     133 # propagate_type: (x: OptPairTensor)
# --> 134 out = self.propagate(edge_index, x=x, size=size)
#     135 out = self.lin_l(out)
#     137 x_r = x[1]
#
# File ~\AppData\Local\Temp\torch_geometric.nn.conv.sage_conv_SAGEConv_propagate_yubc1efo.py:229, in propagate(self, edge_index, x, size)
#     221             kwargs = CollectArgs(
#     222                 x_j=kwargs.x_j,
#     223                 index=hook_kwargs['index'],
#     224                 ptr=hook_kwargs['ptr'],
#     225                 dim_size=hook_kwargs['dim_size'],
#     226             )
#     227 # End Aggregate Forward Pre Hook #######################################
# --> 229 out = self.aggregate(
#     230     out,
#     231     index=kwargs.index,
#     232     ptr=kwargs.ptr,
#     233     dim_size=kwargs.dim_size,
#     234 )
#     236 # Begin Aggregate Forward Hook #########################################
#     237 if not torch.jit.is_scripting() and not is_compiling():
#
# File c:\Users\fathi\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch_geometric\nn\conv\message_passing.py:594, in MessagePassing.aggregate(self, inputs, index, ptr, dim_size)
#     577 def aggregate(
#     578     self,
#     579     inputs: Tensor,
#    (...)
#     582     dim_size: Optional[int] = None,
#     583 ) -> Tensor:
#     584     r"""Aggregates messages from neighbors as
#     585     :math:`\bigoplus_{j \in \mathcal{N}(i)}`.
#     586
#    (...)
#     592     as specified in :meth:`__init__` by the :obj:`aggr` argument.
#     593     """
# --> 594     return self.aggr_module(inputs, index, ptr=ptr, dim_size=dim_size,
#     595                             dim=self.node_dim)
#
# File c:\Users\fathi\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch_geometric\experimental.py:117, in disable_dynamic_shapes.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     114 @functools.wraps(func)
#     115 def wrapper(*args: Any, **kwargs: Any) -> Any:
#     116     if not is_experimental_mode_enabled('disable_dynamic_shapes'):
# --> 117         return func(*args, **kwargs)
#     119     for required_arg in required_args:
#     120         index = required_args_pos[required_arg]
#
# File c:\Users\fathi\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch_geometric\nn\aggr\base.py:131, in Aggregation.__call__(self, x, index, ptr, dim_size, dim, **kwargs)
#     128     dim_size = int(index.max()) + 1 if index.numel() > 0 else 0
#     130 try:
# --> 131     return super().__call__(x, index=index, ptr=ptr, dim_size=dim_size,
#     132                             dim=dim, **kwargs)
#     133 except (IndexError, RuntimeError) as e:
#     134     if index is not None:
#
# File c:\Users\fathi\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Users\fathi\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File c:\Users\fathi\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch_geometric\nn\aggr\basic.py:36, in MeanAggregation.forward(self, x, index, ptr, dim_size, dim)
#      33 def forward(self, x: Tensor, index: Optional[Tensor] = None,
#      34             ptr: Optional[Tensor] = None, dim_size: Optional[int] = None,
#      35             dim: int = -2) -> Tensor:
# ---> 36     return self.reduce(x, index, ptr, dim_size, dim, reduce='mean')
#
# File c:\Users\fathi\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch_geometric\nn\aggr\base.py:185, in Aggregation.reduce(self, x, index, ptr, dim_size, dim, reduce)
#     182 if index is None:
#     183     raise RuntimeError("Aggregation requires 'index' to be specified")
# --> 185 return scatter(x, index, dim, dim_size, reduce)
#
# File c:\Users\fathi\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch_geometric\utils\_scatter.py:79, in scatter(src, index, dim, dim_size, reduce)
#      77 if reduce == 'mean':
#      78     count = src.new_zeros(dim_size)
# ---> 79     count.scatter_add_(0, index, src.new_ones(src.size(dim)))
#      80     count = count.clamp(min=1)
#      82     index = broadcast(index, src, dim)
#
# KeyboardInterrupt:

# %%
'''MODEL EXPLANATION RESULTS WOULD BE SOMETHING LIKE THIS
==================================================
Total subjects analyzed: 52
Prediction accuracy: 0.5769

BAND IMPORTANCE SUMMARY:

Alpha Band:
  Average node importance: 0.0234 ± 0.0089
  Average feature importance: 0.0187 ± 0.0056
  Average temporal importance: 0.0198 ± 0.0067

Beta Band:
  Average node importance: 0.0456 ± 0.0123
  Average feature importance: 0.0398 ± 0.0098
  Average temporal importance: 0.0421 ± 0.0087

OVERALL BAND IMPORTANCE:
Alpha: 0.0234 ± 0.0089
Beta: 0.0456 ± 0.0123

GLOBAL NODE IMPORTANCE (across all bands & subjects):
  Node 15: 0.0523 ± 0.0145
  Node 8: 0.0498 ± 0.0134
  Node 12: 0.0487 ± 0.0128
  Node 3: 0.0465 ± 0.0119
  Node 7: 0.0443 ± 0.0112

GLOBAL FEATURE IMPORTANCE (across all bands & subjects):
  Feature 2: 0.0612 ± 0.0167
  Feature 0: 0.0578 ± 0.0145
  Feature 1: 0.0534 ± 0.0139
  Feature 4: 0.0498 ± 0.0123
  Feature 3: 0.0456 ± 0.0118

CLASS-WISE NODE IMPORTANCE (per class label):

Class 0:
  Node 15: 0.0534
  Node 8: 0.0512
  Node 12: 0.0489
  Node 3: 0.0467
  Node 7: 0.0445

Class 1:
  Node 12: 0.0598
  Node 15: 0.0567
  Node 8: 0.0534
  Node 3: 0.0512
  Node 7: 0.0489

CLASS-WISE FEATURE IMPORTANCE (per class label):

Class 0:
  Feature 2: 0.0623
  Feature 0: 0.0589
  Feature 1: 0.0545
  Feature 4: 0.0512
  Feature 3: 0.0467

Class 1:
  Feature 2: 0.0634
  Feature 0: 0.0598
  Feature 1: 0.0567
  Feature 4: 0.0534
  Feature 3: 0.0489'''
